# %%
import pandas as pd
import numpy as np
import sys
sys.path.append(r'D:\E-Commerce_dynamic_system\src')

# %%
#loading cleaned dataframe
df=pd.read_csv(r'D:\E-Commerce_dynamic_system\data\processed\cleaned_products.csv',index_col=0)

# %%
print("Data Loaded",df.shape)
# Out:
# Data Loaded (41651, 11)

# %%
from feature_engineering import engineer_all_features

# %%
#applying feature engineering
df=engineer_all_features(df)
print("Features Added",df.shape)
# Out:
# Features Added (41651, 19)

# %%
df.columns.tolist()
# Out:
# ['title',
#  'rating',
#  'number_of_reviews',
#  'bought_in_last_month',
#  'current/discounted_price',
#  'listed_price',
#  'is_best_seller',
#  'is_sponsored',
#  'is_couponed',
#  'sustainability_badges',
#  'collected_at',
#  'discounted_amount',
#  'discount_pct',
#  'value_score',
#  'demand_score',
#  'estimated_revenue',
#  'price_category',
#  'revenue_leakage_pct',
#  'premium_price_flag']

# %%
df.head()
# Out:
#                                                title  rating  \
# 0  BOYA BOYALINK 2 Wireless Lavalier Microphone f...     4.6
# 1  LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...     4.3
# 2  DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...     4.6
# 3  Apple AirPods Pro 2 Wireless Earbuds, Active N...     4.6
# 4  Apple AirTag 4 Pack. Keep Track of and find Yo...     4.8
#
#    number_of_reviews  bought_in_last_month  current/discounted_price  \
# 0              375.0                 300.0                     89.68
# 1             2457.0                6000.0                      9.99
# 2             3044.0                2000.0                    314.00
# 3            35882.0               10000.0                     77.00
# 4            28988.0               10000.0                     77.00
#
#    listed_price  is_best_seller  is_sponsored  is_couponed  \
# 0        159.00               0             1            0
# 1         15.99               0             1            0
# 2        349.00               0             1            0
# 3         56.99               1             0            0
# 4         56.99               0             0            0
#
#    sustainability_badges         collected_at  discounted_amount  \
# 0                      0  2025-08-21 11:14:29              69.32
# 1                      1  2025-08-21 11:14:29               6.00
# 2                      1  2025-08-21 11:14:29              35.00
# 3                      1  2025-08-21 11:14:29             -20.01
# 4                      1  2025-08-21 11:14:29             -20.01
#
#    discount_pct  value_score  demand_score  estimated_revenue price_category  \
# 0     43.597484     0.051293         0.003            26904.0      Mid-range
# 1     37.523452     0.430430         0.060            59940.0         Budget
# 2     10.028653     0.014650         0.020           628000.0        Premium
# 3    -35.111423     0.059740         0.100           770000.0      Mid-range
# 4    -35.111423     0.062338         0.100           770000.0      Mid-range
#
#    revenue_leakage_pct  premium_price_flag
# 0            43.597484                   0
# 1            37.523452                   0
# 2            10.028653                   0
# 3             0.000000                   1
# 4             0.000000                   1

# %% [markdown]
# Performed discretization-Converts continuous numerical values into discrete categories/bins.In this case it would help to compare and analyze the range like how much % of the products are underbudget,mid-range and premium.

# %%
df['revenue_leakage_pct'].describe()
# Out:
# count    41651.000000
# mean        14.282815
# std         22.578620
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%         21.476074
# max         93.700649
# Name: revenue_leakage_pct, dtype: float64

# %%
df['premium_price_flag'].describe()
# Out:
# count    41651.000000
# mean         0.567910
# std          0.495373
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: premium_price_flag, dtype: float64
